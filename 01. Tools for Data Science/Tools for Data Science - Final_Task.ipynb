# %% [markdown]
# #  "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# <b>Joshua.<br>
# Focused on becoming a Data Scientist.</b>

# %% [markdown]
# <i>"I am interested in data science because I want to change the career in which I'm currently at. Hopefully this will be a upgrade on my professional career."</i>

# %%
# Program to generate a random number between 0 and 9

# importing the random module
import random

print(random.randint(0,9))
# Out:
# 6

# %% [markdown]
# <h2>Favorite National Teams to win the FIFA World Cup</h2>
# <ul>
#     <li>Brasil</li>
#     <li>Germany</li>
#     <li>Argentina</li>
#     <li>France</li>
# </ul>
#
# <hr>
#
# <h3>Now the order in Which the National team will finish the Qatar World Cup</h3>
# <ol>
#     <li>Brasil</li>
#     <li>Germany</li>
#     <li>France</li>
#     <li>Argentina</li>
# </ol>
#
# <hr>
#
# <s>Well, just because it was asked, the strikethrough is here</s>
#
#
# <hr>
#
# <blockquote>Also, I coudn't leave behind the blockes quote asked for. And iykyk. Life will hit you, but a true man is the one that can take those hits and keep moving forward</blockquote>
#
#
# <hr>
#
# <img src="https://pittsburghsoccernow.com/wp-content/uploads/2022/11/World-Cup.jpg">
